# %% [markdown]
#   ## Kalyani Dhondge
#
#
# **1.What are escape characters, and how do you use them?**
#
# -> In python there are some strings or character which are illegal. We are not able to use them So in order to use those strings or character we need the escape character. This character is basically backslash '\' followed by the character which you want to have in your syntax.
#
# Eg: print(' I don\'t want to use any other /tlanguage')
#
# o/p: 'I don't want to use any other   language')
#
# Other:
# \' -->Single Quote
# \\ -->Backslash
# \n -->New Line
# \r -->Carriage Return
# \t --> Tab
# \b -->Backspace
#
# **2.What do the escape characters n and t stand for?**
#
# ->  \n: Next line
#     \t: tab
#
#
# **3. What is the way to include backslash characters in a string?**
#
# ->  using \\
#     eg: print('I don\\t want to use any other language')
#
#
# **4. The string How Moving Castle is a correct value. Why isn t the single quote character in the
#      word Howls not escaped a problem? **
#
# ->   Because in python we can use single quotes inside the double quote and vice versa i.e. we can also put double quotes insid ethe single quote
#
#
# **5. How do you write a string of newlines if you dont want to use the n character?**
#
# =>  By just writing **print()**
#
#
# **6. What are the values of the given expressions?**
#
# 'Hello, world!'[1]
# 'Hello, world!'[0:5]
# 'Hello, world!'[:5]
# 'Hello, world!'[3:]
#
# =>
# 'Hello, world!'[1] --> 'e'
# 'Hello, world!'[0:5] --> 'Hello'
# 'Hello, world!'[:5] --> 'Hello'
# 'Hello, world!'[3:] --> 'lo, world!
#
#
# **7. What are the values of the following expressions?**
#
# 'Hello'.upper()
# 'Hello'.upper().isupper()
# 'Hello'.upper().lower()
#
# =>
# 'Hello'.upper() --> 'HELLO'
# 'Hello'.upper().isupper() --> False
# 'Hello'.upper().lower() -->'Hello--> hello
#
# **8. What are the values of the following expressions?**
#
# 'Remember, remember, the fifth of November.'.split()
# '-'.join('There can be only one.'.split())
#
# ->
# 'Remember, remember, the fifth of November.'.split() --> ['Remember', 'remember', 'the', 'fifth, 'of', 'November.']
# '-'.join('There can be only one.'.split()) --> 'There-can-be-only-one.'
#
#
# **9. What are the methods for right-justifying, left-justifying, and centering a string?**
#
# =>
# 'string'.center(width): center
# 'string'.rjust(width): right justify
# 'string'.ljust(width): left justify
#
#
# **10. What is the best way to remove whitespace characters from the start or end?**
#
# =>  using strip() method. It removes the white spaces at left and at the right side of the string
# example: string.strip()
